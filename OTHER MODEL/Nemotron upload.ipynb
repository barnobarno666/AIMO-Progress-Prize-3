# %%
import kagglehub
kagglehub.login()

# %%
import huggingface_hub 
model=huggingface_hub.snapshot_download("unsloth/NVIDIA-Nemotron-3-Super-120B-A12B-NVFP4" , local_dir="NEMOTRON MODEL")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# ...
# Fetching 36 files:   0%|          | 0/36 [00:00<?, ?it/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
print(model)
# Out:
# /content/NEMOTRON MODEL

# %%
handle = 'barnobarno/NVIDIA-Nemotron-3-Super-120B-A12B-NVFP4/Transformers/NVFP4'
local_model_dir = model

kagglehub.model_upload(handle, local_model_dir)
# Out:
# Uploading Model https://www.kaggle.com/models/barnobarno/NVIDIA-Nemotron-3-Super-120B-A12B-NVFP4/Transformers/NVFP4 ...
# Model 'NVIDIA-Nemotron-3-Super-120B-A12B-NVFP4' does not exist or access is forbidden for user 'barnobarno'. Creating or handling Model...
# ...
# Model 'NVIDIA-Nemotron-3-Super-120B-A12B-NVFP4' Created.
# Starting upload for file /content/NEMOTRON MODEL/README.md
# ...
# Uploading: 100%|██████████| 78.6k/78.6k [00:00<00:00, 84.0kB/s]
# Upload successful: /content/NEMOTRON MODEL/README.md (77KB)
# Starting upload for file /content/NEMOTRON MODEL/chat_template.jinja
# ...
# Uploading: 100%|██████████| 10.8k/10.8k [00:00<00:00, 13.2kB/s]
# Upload successful: /content/NEMOTRON MODEL/chat_template.jinja (11KB)
# Starting upload for file /content/NEMOTRON MODEL/super_v3_reasoning_parser.py
# ...
# Uploading: 100%|██████████| 1.88k/1.88k [00:00<00:00, 2.44kB/s]
# Upload successful: /content/NEMOTRON MODEL/super_v3_reasoning_parser.py (2KB)
# ...
