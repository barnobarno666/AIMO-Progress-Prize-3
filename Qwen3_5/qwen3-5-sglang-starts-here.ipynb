# %% [markdown]
# # Qwen3.5 Lab for [AIMO3](https://www.kaggle.com/competitions/ai-mathematical-olympiad-progress-prize-3)
# ## By [暗黑AGI](https://www.kaggle.com/boristown)
# ### Reference [huggingface.co](https://huggingface.co/Qwen/Qwen3.5-27B)

# %%
import time
# Record the absolute start time of the entire notebook session
GLOBAL_START_TIME = time.time()
print(f"Notebook session started at: {GLOBAL_START_TIME}")
# Out:
# Notebook session started at: 1773224530.1136498

# %%
# !uv pip install -q --no-index --find-links=/kaggle/input/datasets/boristown/qwen3-5wheels/wheels/ nvidia-cudnn-cu12==9.16.0.29

# !uv pip install -q --no-index --find-links=/kaggle/input/datasets/boristown/qwen3-5wheels/wheels/ flashinfer

# !uv pip install -q --no-index --find-links=/kaggle/input/datasets/barnobarno/sglang-wheels sglang[all]

# !uv pip install -q --no-index --find-links=/kaggle/input/datasets/barnobarno/sglang-wheels-v2 openai

# %%
import sglang

# %%
import os
import json
import subprocess
import tempfile
import traceback
import time
import re
import pandas as pd
import polars as pl
import kaggle_evaluation.aimo_3_inference_server

from openai import OpenAI

# =====================================================================
# 1. Configuration
# =====================================================================
TIME_LIMIT_SECONDS = 4 * 3600 + 45 * 60
MAX_TURNS = 128
PROBLEM_TIME_LIMIT = 900

# Phase 3: Configurable CSV path for local evaluation
LOCAL_CSV_PATH = '/kaggle/input/ai-mathematical-olympiad-progress-prize-3/reference.csv'

# =====================================================================
# 2. Python Tool Definition (OpenAI function-calling schema)
# =====================================================================
PYTHON_TOOL = {
    'type': 'function',
    'function': {
        'name': 'python_executor',
        'description': (
            'Executes Python code locally. '
            'Pre-installed packages include math, numpy, sympy, etc. '
            'STRICT LIMIT: Script must finish within 7 seconds. '
            'Use this to solve math problems, calculate equations, or process data. '
            'MUST use print() to output the final result.'
        ),
        'parameters': {
            'type': 'object',
            'properties': {
                'code': {
                    'type': 'string',
                    'description': 'The Python script code to execute.'
                }
            },
            'required': ['code']
        }
    }
}

# =====================================================================
# 3. Standalone Python Executor (subprocess-based, 7s timeout)
# =====================================================================
def execute_python(code: str) -> str:
    """Execute Python code in a subprocess with a 7-second timeout."""
    with tempfile.NamedTemporaryFile(mode='w', suffix='.py', delete=False) as f:
        f.write(code)
    script_path = f.name

    try:
        result = subprocess.run(
            ["python", script_path],
            capture_output=True,
            text=True,
            timeout=7
        )
        output = result.stdout

        if result.stderr:
            output += (
                f"\n[Execution Error]:\n{result.stderr}\n"
                "System Note: Please debug the above error. "
                "If a purely computational approach is failing, consider solving it algebraically first. "
                "Provide the corrected script below."
            )
        if not output.strip():
            output = "Code executed successfully, but nothing was printed. Use print() to output the answer."

        if len(output) > 2000:
            output = output[:1000] + "\n\n... [OUTPUT TRUNCATED] ...\n\n" + output[-1000:]

        return output

    except subprocess.TimeoutExpired:
        return (
            "System: Execution timed out after 7 seconds. "
            "The current approach is computationally too expensive. "
            "Please analyze the bottleneck internally and write a more efficient Python script "
            "(e.g., using mathematical simplification, SymPy, or dynamic programming). "
            "Please output the updated code block directly."
        )
    except Exception:
        return f"System Execution failed:\n{traceback.format_exc()}"
    finally:
        if os.path.exists(script_path):
            os.remove(script_path)


# =====================================================================
# 4. Model Class with SGLang Server + Direct OpenAI API TIR Loop
# =====================================================================
class Model:
    """Manages the SGLang server and runs TIR via the OpenAI-compatible API."""

    def __init__(self):
        self._model = None
        self.system_instruction = (
            'You are an elite mathematical AI operating inside a fast-paced, multi-turn Agent framework. '
            'Your goal is to solve IMO-level problems strictly through Python code execution, not manual text derivation.\n\n'
            '# Agent Execution Rules & State Machine:\n'
            '1. CONCISE WORKFLOW: Keep text explanations extremely brief. Use inline comments within your Python code for planning.\n'
            '2. CONTINUOUS EXECUTION: In every intermediate round, instantly invoke the `python_executor` tool to test hypotheses, calculate, or find patterns.\n'
            '3. READ & REACT: Based on the observation, write the next block of code to debug or progress. Keep text outside code blocks to an absolute minimum.\n'
            '4. HARD LIMITS: Python execution is strictly capped at 7 seconds. Optimize algorithms to avoid timeouts.\n'
            '5. MANDATORY VERIFICATION PHASE (CRITICAL): You are FORBIDDEN from outputting a final answer immediately after finding a potential solution. '
            'Before your final output, you MUST write a dedicated verification script. This script must verify the proposed answer using a COMPLETELY DIFFERENT mathematical method, or by plugging the answer back into the original problem constraints. '
            'Only if this independent verification script runs successfully and confirms the exact same result, may you proceed to the final output.\n'
            '6. ZERO GUESSING: If the verification script fails, times out, or yields a contradiction, you MUST discard the answer and write new code to find the flaw.\n\n'
            '# FINAL OUTPUT FORMAT (CRITICAL):\n'
            'The final answer must be a single non-negative integer between 0 and 99999.\n'
            'Once you have explicitly received a positive confirmation from your verification script, STOP CODING.\n'
            'Your final response MUST be exclusively the boxed answer and absolutely nothing else. '
            'DO NOT write summaries, reasoning, or text explanations.\n'
            'Example: \\boxed{42}'
        )

    def load(self):
        """Start the SGLang server and return the _predict callable."""
        print("Loading model and starting SGLang server...")
        import requests

        # SGLang JIT Workaround for Kaggle read-only environment
        custom_lib_dir = "/tmp/custom_cuda_lib"
        os.makedirs(custom_lib_dir, exist_ok=True)
        libcuda_path = os.popen("find /usr -name libcuda.so.1 2>/dev/null | head -n 1").read().strip()
        if libcuda_path:
            os.system(f"ln -sf {libcuda_path} {custom_lib_dir}/libcuda.so")
            os.environ["LIBRARY_PATH"] = f"{custom_lib_dir}:{os.environ.get('LIBRARY_PATH', '')}"
            os.environ["LD_LIBRARY_PATH"] = f"{custom_lib_dir}:{os.environ.get('LD_LIBRARY_PATH', '')}"
        os.environ["SGLANG_DISABLE_CUDNN_CHECK"] = "1"

        # Phase 1: Fixed SGLang server flags
        command = [
            "python", "-m", "sglang.launch_server",
            "--model-path", "/kaggle/input/models/barnobarno/qwen3.5-4b/transformers/unsloth/1",
            "--port", "8000",
            "--tp-size", "1",
            "--mem-fraction-static", "0.88",        # Increased from 0.85, safe with FP8 KV
            "--context-length", "131072",
            "--max-prefill-tokens", "8192",
            "--chunked-prefill-size", "8192",        # H100 optimization: explicit chunked prefill
            "--kv-cache-dtype", "fp8_e4m3",          # H100 optimization: ~50% KV memory savings
            "--reasoning-parser", "qwen3",           # Properly separate thinking from output
            "--tool-call-parser", "qwen",            # BUG FIX: 'qwen' for Qwen series (not qwen3_coder)
            "--enable-auto-tool-choice",             # Required for native function calling
            "--language-only",                       # Skip multimodal encoder (text only for AIMO)
            "--disable-log-stats",                   # Reduce logging overhead
        ]

        self.process = subprocess.Popen(command, stdout=open('server.log', 'w'), stderr=subprocess.STDOUT)

        api_url = "http://0.0.0.0:8000/v1/models"
        for attempt in range(1, 30):
            if self.process.poll() is not None:
                print("❌ SGLang process crashed! Check server.log.")
                break
            try:
                response = requests.get(api_url, timeout=5)
                if response.status_code == 200:
                    print(f"✅ Server started successfully!")
                    break
            except Exception:
                pass
            time.sleep(60)

        # Phase 2: Create OpenAI client for TIR
        client = OpenAI(
            base_url="http://0.0.0.0:8000/v1",
            api_key="EMPTY",
            timeout=120,
        )

        system_instruction = self.system_instruction

        def _predict(problem_text: str) -> int:
            # Check global time limit
            try:
                elapsed = time.time() - GLOBAL_START_TIME
                if elapsed >= TIME_LIMIT_SECONDS:
                    print(f"⚠️ Global time limit reached ({elapsed:.0f}s elapsed). Outputting 0 directly.")
                    return 0
            except NameError:
                pass

            messages = [
                {'role': 'system', 'content': system_instruction},
                {'role': 'user', 'content': problem_text},
            ]
            final_answer = 0
            problem_start_time = time.time()

            try:
                for turn in range(MAX_TURNS):
                    # Check per-problem timeout
                    if time.time() - problem_start_time > PROBLEM_TIME_LIMIT:
                        print(f"\n⚠️ [Circuit Breaker] Time limit exceeded ({PROBLEM_TIME_LIMIT}s). Halting!")
                        break

                    # Check global time limit
                    try:
                        if time.time() - GLOBAL_START_TIME >= TIME_LIMIT_SECONDS:
                            print(f"⚠️ Global time limit reached. Halting!")
                            break
                    except NameError:
                        pass

                    # Call the model via OpenAI-compatible API
                    response = client.chat.completions.create(
                        model="Qwen/Qwen3.5-35B-A3B",
                        messages=messages,
                        tools=[PYTHON_TOOL],
                        temperature=1.0,
                        top_p=1.0,
                        max_tokens=24576,
                        presence_penalty=2.0,
                        extra_body={
                            'chat_template_kwargs': {'enable_thinking': False},
                            'top_k': 40,
                            'min_p': 0.0,
                            'repetition_penalty': 1.0,
                        },
                    )

                    choice = response.choices[0]
                    assistant_msg = choice.message
                    content_text = assistant_msg.content or ''

                    # Check if model made tool calls
                    if assistant_msg.tool_calls:
                        # Extract code from the first python_executor call
                        tool_call = assistant_msg.tool_calls[0]
                        try:
                            args = json.loads(tool_call.function.arguments)
                            code = args.get('code', '')
                        except (json.JSONDecodeError, AttributeError):
                            code = tool_call.function.arguments

                        print(f"Turn {turn+1} | tool_call | code length: {len(code)}")

                        # Execute the code
                        tool_output = execute_python(code)

                        # Append assistant message with tool_calls
                        messages.append({
                            'role': 'assistant',
                            'content': content_text if content_text else None,
                            'tool_calls': [
                                {
                                    'id': tc.id,
                                    'type': 'function',
                                    'function': {
                                        'name': tc.function.name,
                                        'arguments': tc.function.arguments,
                                    }
                                }
                                for tc in assistant_msg.tool_calls
                            ],
                        })

                        # Append tool result
                        messages.append({
                            'role': 'tool',
                            'tool_call_id': tool_call.id,
                            'content': tool_output,
                        })

                        snippet = tool_output.replace('\n', ' ')[:80]
                        print(f"Turn {turn+1} | tool_result | {snippet}")
                        continue

                    # No tool calls — model produced a final text response
                    print(f"Turn {turn+1} | assistant | [FINAL CONTENT]:\n{content_text}")

                    matches = re.findall(r'\\boxed\{(\d+)\}', content_text)
                    if matches:
                        try:
                            ans = int(matches[-1])
                            final_answer = ans % 100000 if ans > 99999 or ans < 0 else ans
                        except ValueError:
                            pass
                    break

            except Exception as e:
                print(f"Error during reasoning: {e}")

            return final_answer

        return _predict

    def predict(self, problem: str):
        if self._model is None:
            self._model = self.load()
        return self._model(problem)


model = Model()


# =====================================================================
# 5. Local Evaluation Monitor (Side-car logic: safely ignored during submission)
# =====================================================================
IS_LOCAL_RUN = not os.getenv('KAGGLE_IS_COMPETITION_RERUN')
expected_answers = {}
local_correct = 0
local_total = 0

if IS_LOCAL_RUN:
    try:
        if os.path.exists(LOCAL_CSV_PATH):
            df_ref = pd.read_csv(LOCAL_CSV_PATH)
            if 'answer' in df_ref.columns and 'id' in df_ref.columns:
                expected_answers = dict(zip(df_ref['id'], df_ref['answer']))
    except Exception:
        pass


def predict(id_: pl.Series, problem: pl.Series) -> pl.DataFrame:
    """Make a prediction for the AIMO3 server."""
    global local_correct, local_total

    id_val = id_.item(0)
    problem_text = problem.item(0)

    print(f"\n========== Evaluating ID: {id_val} ==========")
    prediction = model.predict(problem_text)
    print(f"Result for {id_val}: {prediction}")

    if IS_LOCAL_RUN and id_val in expected_answers:
        expected = expected_answers[id_val]
        is_correct = str(prediction) == str(expected)

        if is_correct:
            local_correct += 1
            print(f"✅ Auto-Eval: Correct! (Expected: {expected})")
        else:
            print(f"❌ Auto-Eval: Incorrect! (Expected: {expected})")

        local_total += 1
        current_acc = (local_correct / local_total) * 100
        print(f"📊 Running Accuracy: {local_correct}/{local_total} ({current_acc:.2f}%)")

    print("=============================================\n")

    return pl.DataFrame({'id': id_val, 'answer': prediction})

# =====================================================================
# 6. Phase 3: Flexible CSV Handling + Server Launch
# =====================================================================
inference_server = kaggle_evaluation.aimo_3_inference_server.AIMO3InferenceServer(predict)

if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
    inference_server.serve()
else:
    original_csv = LOCAL_CSV_PATH
    mock_csv = '/kaggle/working/mock_reference.csv'

    if os.path.exists(original_csv):
        df_raw = pd.read_csv(original_csv)

        # Handle arbitrary CSVs: require 'problem' column, optional 'id' and 'answer'
        # Auto-detect column: try 'problem' first, then 'question'
        problem_col = None
        for col_name in ['problem', 'question']:
            if col_name in df_raw.columns:
                problem_col = col_name
                break

        if problem_col is None:
            raise ValueError(f"CSV must have a 'problem' or 'question' column. Found: {list(df_raw.columns)}")

        # Rename to 'problem' if needed (the inference server expects 'problem')
        if problem_col != 'problem':
            df_raw = df_raw.rename(columns={problem_col: 'problem'})

        # Generate sequential IDs if no 'id' column
        if 'id' not in df_raw.columns:
            df_raw['id'] = range(len(df_raw))

        # Load answers for local eval scoring (if available)
        if 'answer' in df_raw.columns:
            expected_answers.update(dict(zip(df_raw['id'], df_raw['answer'])))

        # Create mock CSV with only id + problem (strip answer)
        df_clean = df_raw[['id', 'problem']].copy()
        df_clean.to_csv(mock_csv, index=False)
        print(f"📁 [Local Setup] Created mock test set: {len(df_clean)} problems from {original_csv}")
    else:
        print(f"⚠️ CSV not found at {original_csv}. Using default Kaggle test set.")
        mock_csv = '/kaggle/input/ai-mathematical-olympiad-progress-prize-3/test.csv'

    inference_server.run_local_gateway((mock_csv,))
# Out:
# 📁 [Local Setup] Created mock test set: 10 problems from /kaggle/input/ai-mathematical-olympiad-progress-prize-3/reference.csv
#
# ========== Evaluating ID: a295e9 ==========
# Loading model and starting SGLang server...
# ❌ SGLang process crashed! Check server.log.
# Error during reasoning: Connection error.
# Result for a295e9: 0
# ❌ Auto-Eval: Incorrect! (Expected: 520)
# 📊 Running Accuracy: 0/1 (0.00%)
# =============================================
#
#
# ========== Evaluating ID: 92ba6a ==========
# Error during reasoning: Connection error.
# Result for 92ba6a: 0
# ❌ Auto-Eval: Incorrect! (Expected: 50)
# 📊 Running Accuracy: 0/2 (0.00%)
# =============================================
#
#
# ========== Evaluating ID: 424e18 ==========
# Error during reasoning: Connection error.
# Result for 424e18: 0
# ❌ Auto-Eval: Incorrect! (Expected: 21818)
# 📊 Running Accuracy: 0/3 (0.00%)
# =============================================
#
#
# ========== Evaluating ID: 0e644e ==========
# Error during reasoning: Connection error.
# Result for 0e644e: 0
# ❌ Auto-Eval: Incorrect! (Expected: 336)
# 📊 Running Accuracy: 0/4 (0.00%)
# =============================================
#
#
# ========== Evaluating ID: 86e8e5 ==========
# Error during reasoning: Connection error.
# Result for 86e8e5: 0
# ❌ Auto-Eval: Incorrect! (Expected: 8687)
# 📊 Running Accuracy: 0/5 (0.00%)
# =============================================
#
#
# ========== Evaluating ID: 26de63 ==========
# Error during reasoning: Connection error.
# Result for 26de63: 0
# ❌ Auto-Eval: Incorrect! (Expected: 32951)
# 📊 Running Accuracy: 0/6 (0.00%)
# =============================================
#
#
# ========== Evaluating ID: 42d360 ==========
# Error during reasoning: Connection error.
# Result for 42d360: 0
# ❌ Auto-Eval: Incorrect! (Expected: 32193)
# 📊 Running Accuracy: 0/7 (0.00%)
# =============================================
#
#
# ========== Evaluating ID: 9c1c5f ==========
# Error during reasoning: Connection error.
# Result for 9c1c5f: 0
# ❌ Auto-Eval: Incorrect! (Expected: 580)
# 📊 Running Accuracy: 0/8 (0.00%)
# =============================================
#
#
# ========== Evaluating ID: dd7f5e ==========
# Error during reasoning: Connection error.
# Result for dd7f5e: 0
# ❌ Auto-Eval: Incorrect! (Expected: 160)
# 📊 Running Accuracy: 0/9 (0.00%)
# =============================================
#
#
# ========== Evaluating ID: 641659 ==========
# Error during reasoning: Connection error.
# Result for 641659: 0
# ❌ Auto-Eval: Incorrect! (Expected: 57447)
# 📊 Running Accuracy: 0/10 (0.00%)
# =============================================
